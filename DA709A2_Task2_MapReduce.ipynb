# %% [markdown]
# <a href="https://colab.research.google.com/github/hxiufan/709A2/blob/main/DA709A2_Task2_MapReduce.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#set up PySpark on my cluster. Ensure Spark is installed and configured properly.
from pyspark import SparkContext, SparkConf
import csv

# Create a SparkContext
conf = SparkConf().setAppName("SpotifyTracksAnalysis")
sc = SparkContext(conf=conf)

# %%
# Mount my Google Drive
from google.colab import drive

# %%
# load the data into an RDD and preprocess it.
lines = sc.textFile("/content/drive/My Drive/DA709/cleaned_spotify_tracks.csv")
raw_data = sc.textFile("/content/drive/My Drive/DA709/cleaned_spotify_tracks.csv")

# %%
# Parse CSV lines and split fields
def parse_line(line):
    reader = csv.reader([line])
    return next(reader)

# %%
# Filter out header and parse rows
header = raw_data.first()
data = raw_data.filter(lambda line: line != header).map(parse_line)

# %%
# Extract selected fields and convert to tuple
# CSV columns: (name, genre, artists, album, popularity, duration_ms, explicit)
rdd = data.map(lambda row: (row[2], row[1], int(row[5]), int(row[6])))

# %%
# Perform MapReduce operations
# Aggregate by artist to calculate sum, average, and count
artist_stats = rdd.map(lambda x: (x[0], (x[2], 1, x[3]))) \
    .reduceByKey(lambda a, b: (a[0] + b[0], a[1] + b[1], a[2] + b[2]))

# %%
# Calculate statistics
artist_result = artist_stats.map(lambda x: (x[0], {
    "total_duration_ms": x[1][0],
    "average_duration_ms": x[1][0] / x[1][1],
    "count_tracks": x[1][1],
    "total_explicit_count": x[1][2]
}))

# %%
# Collect and display the results
results = artist_result.collect()

# %%
# Print the results
for artist, stats in results:
    print(f"Artist: {artist}")
    print(f"  Total Duration (ms): {stats['total_duration_ms']}")
    print(f"  Average Duration (ms): {stats['average_duration_ms']:.2f}")
    print(f"  Track Count: {stats['count_tracks']}")
    print(f"  Total Explicit Count: {stats['total_explicit_count']}")
    print("-" * 40)
# Out:
# Artist: alt-rock
#   Total Duration (ms): 1509
#   Average Duration (ms): 30.18
#   Track Count: 50
#   Total Explicit Count: 9867802
# ----------------------------------------
# Artist: ambient
#   Total Duration (ms): 1630
#   Average Duration (ms): 32.60
#   Track Count: 50
#   Total Explicit Count: 7062878
# ----------------------------------------
# Artist: black-metal
#   Total Duration (ms): 1284
#   Average Duration (ms): 25.68
#   Track Count: 50
#   Total Explicit Count: 13926933
# ----------------------------------------
# Artist: blues
#   Total Duration (ms): 1878
#   Average Duration (ms): 37.56
#   Track Count: 50
#   Total Explicit Count: 9887225
# ----------------------------------------
# Artist: bossanova
#   Total Duration (ms): 1276
#   Average Duration (ms): 25.52
#   Track Count: 50
#   Total Explicit Count: 9651849
# ----------------------------------------
# Artist: brazil
#   Total Duration (ms): 2089
#   Average Duration (ms): 41.78
#   Track Count: 50
#   Total Explicit Count: 9296537
# ----------------------------------------
# Artist: cantopop
#   Total Duration (ms): 1080
#   Average Duration (ms): 21.60
#   Track Count: 50
#   Total Explicit Count: 11643536
# ----------------------------------------
# Artist: chicago-house
#   Total Duration (ms): 792
#   Average Duration (ms): 15.84
#   Track Count: 50
#   Total Explicit Count: 12983105
# ----------------------------------------
# Artist: children
#   Total Duration (ms): 1927
#   Average Duration (ms): 38.54
#   Track Count: 50
#   Total Explicit Count: 11086676
# ----------------------------------------
# Artist: chill
#   Total Duration (ms): 2029
#   Average Duration (ms): 40.58
#   Track Count: 50
#   Total Explicit Count: 8374712
# ----------------------------------------
# Artist: club
#   Total Duration (ms): 1900
#   Average Duration (ms): 38.00
#   Track Count: 50
#   Total Explicit Count: 8911406
# ----------------------------------------
# Artist: country
#   Total Duration (ms): 2825
#   Average Duration (ms): 56.50
#   Track Count: 50
#   Total Explicit Count: 10151309
# ----------------------------------------
# Artist: dance
#   Total Duration (ms): 2876
#   Average Duration (ms): 57.52
#   Track Count: 50
#   Total Explicit Count: 10458389
# ----------------------------------------
# Artist: death-metal
#   Total Duration (ms): 1740
#   Average Duration (ms): 34.80
#   Track Count: 50
#   Total Explicit Count: 11503903
# ----------------------------------------
# Artist: detroit-techno
#   Total Duration (ms): 518
#   Average Duration (ms): 10.36
#   Track Count: 50
#   Total Explicit Count: 14664220
# ----------------------------------------
# Artist: disney
#   Total Duration (ms): 2354
#   Average Duration (ms): 47.08
#   Track Count: 50
#   Total Explicit Count: 9028182
# ----------------------------------------
# Artist: edm
#   Total Duration (ms): 1145
#   Average Duration (ms): 22.90
#   Track Count: 50
#   Total Explicit Count: 9671310
# ----------------------------------------
# Artist: electronic
#   Total Duration (ms): 632
#   Average Duration (ms): 14.70
#   Track Count: 43
#   Total Explicit Count: 12653613
# ----------------------------------------
# Artist: french
#   Total Duration (ms): 1314
#   Average Duration (ms): 26.28
#   Track Count: 50
#   Total Explicit Count: 7961561
# ----------------------------------------
# Artist: funk
#   Total Duration (ms): 2235
#   Average Duration (ms): 44.70
#   Track Count: 50
#   Total Explicit Count: 10360036
# ----------------------------------------
# Artist: german
#   Total Duration (ms): 1042
#   Average Duration (ms): 20.84
#   Track Count: 50
#   Total Explicit Count: 6062971
# ----------------------------------------
# Artist: gospel
#   Total Duration (ms): 1466
#   Average Duration (ms): 29.32
#   Track Count: 50
#   Total Explicit Count: 11380616
# ----------------------------------------
# Artist: grunge
#   Total Duration (ms): 1387
#   Average Duration (ms): 27.74
#   Track Count: 50
#   Total Explicit Count: 12105041
# ----------------------------------------
# Artist: guitar
#   Total Duration (ms): 1810
#   Average Duration (ms): 36.20
#   Track Count: 50
#   Total Explicit Count: 9007028
# ----------------------------------------
# Artist: hard-rock
#   Total Duration (ms): 1678
#   Average Duration (ms): 33.56
#   Track Count: 50
#   Total Explicit Count: 9177300
# ----------------------------------------
# Artist: hardcore
#   Total Duration (ms): 1701
#   Average Duration (ms): 34.71
#   Track Count: 49
#   Total Explicit Count: 7633299
# ----------------------------------------
# Artist: heavy-metal
#   Total Duration (ms): 1500
#   Average Duration (ms): 30.61
#   Track Count: 49
#   Total Explicit Count: 10192478
# ----------------------------------------
# Artist: hip-hop
#   Total Duration (ms): 1291
#   Average Duration (ms): 25.82
#   Track Count: 50
#   Total Explicit Count: 12224905
# ----------------------------------------
# Artist: indie
#   Total Duration (ms): 962
#   Average Duration (ms): 19.24
#   Track Count: 50
#   Total Explicit Count: 10322986
# ----------------------------------------
# Artist: indie-pop
#   Total Duration (ms): 936
#   Average Duration (ms): 19.10
#   Track Count: 49
#   Total Explicit Count: 8905869
# ----------------------------------------
# Artist: iranian
#   Total Duration (ms): 818
#   Average Duration (ms): 16.36
#   Track Count: 50
#   Total Explicit Count: 11748530
# ----------------------------------------
# Artist: j-idol
#   Total Duration (ms): 1834
#   Average Duration (ms): 36.68
#   Track Count: 50
#   Total Explicit Count: 10738771
# ----------------------------------------
# Artist: j-pop
#   Total Duration (ms): 1636
#   Average Duration (ms): 33.39
#   Track Count: 49
#   Total Explicit Count: 9107772
# ----------------------------------------
# Artist: jazz
#   Total Duration (ms): 1575
#   Average Duration (ms): 31.50
#   Track Count: 50
#   Total Explicit Count: 8551231
# ----------------------------------------
# Artist: k-pop
#   Total Duration (ms): 343
#   Average Duration (ms): 13.72
#   Track Count: 25
#   Total Explicit Count: 4397527
# ----------------------------------------
# Artist: kids
#   Total Duration (ms): 2411
#   Average Duration (ms): 49.20
#   Track Count: 49
#   Total Explicit Count: 10091047
# ----------------------------------------
# Artist: latin
#   Total Duration (ms): 1503
#   Average Duration (ms): 30.06
#   Track Count: 50
#   Total Explicit Count: 10452663
# ----------------------------------------
# Artist: latino
#   Total Duration (ms): 1074
#   Average Duration (ms): 22.85
#   Track Count: 47
#   Total Explicit Count: 10557995
# ----------------------------------------
# Artist: malay
#   Total Duration (ms): 1098
#   Average Duration (ms): 21.96
#   Track Count: 50
#   Total Explicit Count: 11411054
# ----------------------------------------
# Artist: mandopop
#   Total Duration (ms): 1598
#   Average Duration (ms): 31.96
#   Track Count: 50
#   Total Explicit Count: 12675614
# ----------------------------------------
# Artist: metal-misc
#   Total Duration (ms): 503
#   Average Duration (ms): 10.48
#   Track Count: 48
#   Total Explicit Count: 10796989
# ----------------------------------------
# Artist: minimal-techno
#   Total Duration (ms): 617
#   Average Duration (ms): 12.34
#   Track Count: 50
#   Total Explicit Count: 13140757
# ----------------------------------------
# Artist: movies
#   Total Duration (ms): 1599
#   Average Duration (ms): 31.98
#   Track Count: 50
#   Total Explicit Count: 9667839
# ----------------------------------------
# Artist: new-age
#   Total Duration (ms): 1266
#   Average Duration (ms): 25.84
#   Track Count: 49
#   Total Explicit Count: 9855181
# ----------------------------------------
# Artist: new-release
#   Total Duration (ms): 1858
#   Average Duration (ms): 37.92
#   Track Count: 49
#   Total Explicit Count: 9739859
# ----------------------------------------
# Artist: opera
#   Total Duration (ms): 1712
#   Average Duration (ms): 34.24
#   Track Count: 50
#   Total Explicit Count: 10879866
# ----------------------------------------
# Artist: pagode
#   Total Duration (ms): 2235
#   Average Duration (ms): 44.70
#   Track Count: 50
#   Total Explicit Count: 10998081
# ----------------------------------------
# Artist: party
#   Total Duration (ms): 2711
#   Average Duration (ms): 54.22
#   Track Count: 50
#   Total Explicit Count: 10725275
# ----------------------------------------
# Artist: philippines-opm
#   Total Duration (ms): 1511
#   Average Duration (ms): 30.84
#   Track Count: 49
#   Total Explicit Count: 11422271
# ----------------------------------------
# Artist: piano
#   Total Duration (ms): 959
#   Average Duration (ms): 19.18
#   Track Count: 50
#   Total Explicit Count: 14227775
# ----------------------------------------
# Artist: pop
#   Total Duration (ms): 2658
#   Average Duration (ms): 56.55
#   Track Count: 47
#   Total Explicit Count: 8720998
# ----------------------------------------
# Artist: post-dubstep
#   Total Duration (ms): 701
#   Average Duration (ms): 14.31
#   Track Count: 49
#   Total Explicit Count: 10635325
# ----------------------------------------
# Artist: progressive-house
#   Total Duration (ms): 530
#   Average Duration (ms): 10.60
#   Track Count: 50
#   Total Explicit Count: 9924803
# ----------------------------------------
# Artist: psych-rock
#   Total Duration (ms): 953
#   Average Duration (ms): 19.85
#   Track Count: 48
#   Total Explicit Count: 10759725
# ----------------------------------------
# Artist: punk
#   Total Duration (ms): 1814
#   Average Duration (ms): 36.28
#   Track Count: 50
#   Total Explicit Count: 8569370
# ----------------------------------------
# Artist: punk-rock
#   Total Duration (ms): 821
#   Average Duration (ms): 20.52
#   Track Count: 40
#   Total Explicit Count: 5618533
# ----------------------------------------
# Artist: r-n-b
#   Total Duration (ms): 1728
#   Average Duration (ms): 34.56
#   Track Count: 50
#   Total Explicit Count: 10669017
# ----------------------------------------
# Artist: rainy-day
#   Total Duration (ms): 1780
#   Average Duration (ms): 35.60
#   Track Count: 50
#   Total Explicit Count: 10901927
# ----------------------------------------
# Artist: reggae
#   Total Duration (ms): 1964
#   Average Duration (ms): 40.08
#   Track Count: 49
#   Total Explicit Count: 10231095
# ----------------------------------------
# Artist: reggaeton
#   Total Duration (ms): 1510
#   Average Duration (ms): 38.72
#   Track Count: 39
#   Total Explicit Count: 8770406
# ----------------------------------------
# Artist: road-trip
#   Total Duration (ms): 1247
#   Average Duration (ms): 24.94
#   Track Count: 50
#   Total Explicit Count: 8981350
# ----------------------------------------
# Artist: rock-n-roll
#   Total Duration (ms): 2120
#   Average Duration (ms): 51.71
#   Track Count: 41
#   Total Explicit Count: 9322249
# ----------------------------------------
# Artist: sad
#   Total Duration (ms): 2081
#   Average Duration (ms): 43.35
#   Track Count: 48
#   Total Explicit Count: 9393864
# ----------------------------------------
# Artist: samba
#   Total Duration (ms): 1838
#   Average Duration (ms): 37.51
#   Track Count: 49
#   Total Explicit Count: 9874181
# ----------------------------------------
# Artist: sertanejo
#   Total Duration (ms): 1708
#   Average Duration (ms): 34.16
#   Track Count: 50
#   Total Explicit Count: 9441864
# ----------------------------------------
# Artist: show-tunes
#   Total Duration (ms): 1487
#   Average Duration (ms): 30.35
#   Track Count: 49
#   Total Explicit Count: 9615919
# ----------------------------------------
# Artist: singer-songwriter
#   Total Duration (ms): 981
#   Average Duration (ms): 19.62
#   Track Count: 50
#   Total Explicit Count: 10396621
# ----------------------------------------
# Artist: ska
#   Total Duration (ms): 1581
#   Average Duration (ms): 31.62
#   Track Count: 50
#   Total Explicit Count: 9258653
# ----------------------------------------
# Artist: soul
#   Total Duration (ms): 2627
#   Average Duration (ms): 52.54
#   Track Count: 50
#   Total Explicit Count: 10402032
# ----------------------------------------
# Artist: spanish
#   Total Duration (ms): 1554
#   Average Duration (ms): 31.08
#   Track Count: 50
#   Total Explicit Count: 9761618
# ----------------------------------------
# Artist: summer
#   Total Duration (ms): 2791
#   Average Duration (ms): 56.96
#   Track Count: 49
#   Total Explicit Count: 10145503
# ----------------------------------------
# Artist: swedish
#   Total Duration (ms): 1985
#   Average Duration (ms): 39.70
#   Track Count: 50
#   Total Explicit Count: 11297535
# ----------------------------------------
# Artist: synth-pop
#   Total Duration (ms): 995
#   Average Duration (ms): 19.90
#   Track Count: 50
#   Total Explicit Count: 10086258
# ----------------------------------------
# Artist: tango
#   Total Duration (ms): 1944
#   Average Duration (ms): 38.88
#   Track Count: 50
#   Total Explicit Count: 10273683
# ----------------------------------------
# Artist: techno
#   Total Duration (ms): 1822
#   Average Duration (ms): 37.18
#   Track Count: 49
#   Total Explicit Count: 9736712
# ----------------------------------------
# Artist: turkish
#   Total Duration (ms): 1156
#   Average Duration (ms): 23.12
#   Track Count: 50
#   Total Explicit Count: 9757324
# ----------------------------------------
# Artist: work-out
#   Total Duration (ms): 1266
#   Average Duration (ms): 25.32
#   Track Count: 50
#   Total Explicit Count: 9125553
# ----------------------------------------
# Artist: acoustic
#   Total Duration (ms): 1314
#   Average Duration (ms): 26.28
#   Track Count: 50
#   Total Explicit Count: 9620294
# ----------------------------------------
# Artist: afrobeat
#   Total Duration (ms): 1350
#   Average Duration (ms): 27.00
#   Track Count: 50
#   Total Explicit Count: 15768552
# ----------------------------------------
# Artist: alternative
#   Total Duration (ms): 1257
#   Average Duration (ms): 26.74
#   Track Count: 47
#   Total Explicit Count: 8993720
# ----------------------------------------
# Artist: anime
#   Total Duration (ms): 1372
#   Average Duration (ms): 27.44
#   Track Count: 50
#   Total Explicit Count: 8469309
# ----------------------------------------
# Artist: bluegrass
#   Total Duration (ms): 1251
#   Average Duration (ms): 25.02
#   Track Count: 50
#   Total Explicit Count: 9217160
# ----------------------------------------
# Artist: breakbeat
#   Total Duration (ms): 708
#   Average Duration (ms): 14.16
#   Track Count: 50
#   Total Explicit Count: 11838024
# ----------------------------------------
# Artist: british
#   Total Duration (ms): 1095
#   Average Duration (ms): 21.90
#   Track Count: 50
#   Total Explicit Count: 8474257
# ----------------------------------------
# Artist: classical
#   Total Duration (ms): 1386
#   Average Duration (ms): 27.72
#   Track Count: 50
#   Total Explicit Count: 9675440
# ----------------------------------------
# Artist: comedy
#   Total Duration (ms): 1471
#   Average Duration (ms): 29.42
#   Track Count: 50
#   Total Explicit Count: 8007746
# ----------------------------------------
# Artist: dancehall
#   Total Duration (ms): 1176
#   Average Duration (ms): 24.00
#   Track Count: 49
#   Total Explicit Count: 9418557
# ----------------------------------------
# Artist: deep-house
#   Total Duration (ms): 846
#   Average Duration (ms): 16.92
#   Track Count: 50
#   Total Explicit Count: 8251450
# ----------------------------------------
# Artist: disco
#   Total Duration (ms): 2327
#   Average Duration (ms): 46.54
#   Track Count: 50
#   Total Explicit Count: 10407243
# ----------------------------------------
# Artist: drum-and-bass
#   Total Duration (ms): 1507
#   Average Duration (ms): 30.14
#   Track Count: 50
#   Total Explicit Count: 11743995
# ----------------------------------------
# Artist: dub
#   Total Duration (ms): 1583
#   Average Duration (ms): 31.66
#   Track Count: 50
#   Total Explicit Count: 8667563
# ----------------------------------------
# Artist: dubstep
#   Total Duration (ms): 975
#   Average Duration (ms): 19.50
#   Track Count: 50
#   Total Explicit Count: 10179901
# ----------------------------------------
# Artist: electro
#   Total Duration (ms): 1331
#   Average Duration (ms): 26.62
#   Track Count: 50
#   Total Explicit Count: 9687825
# ----------------------------------------
# Artist: emo
#   Total Duration (ms): 2037
#   Average Duration (ms): 40.74
#   Track Count: 50
#   Total Explicit Count: 9704173
# ----------------------------------------
# Artist: folk
#   Total Duration (ms): 794
#   Average Duration (ms): 15.88
#   Track Count: 50
#   Total Explicit Count: 9309906
# ----------------------------------------
# Artist: forro
#   Total Duration (ms): 1164
#   Average Duration (ms): 23.28
#   Track Count: 50
#   Total Explicit Count: 10116428
# ----------------------------------------
# Artist: garage
#   Total Duration (ms): 1043
#   Average Duration (ms): 20.86
#   Track Count: 50
#   Total Explicit Count: 9523890
# ----------------------------------------
# Artist: goth
#   Total Duration (ms): 1487
#   Average Duration (ms): 29.74
#   Track Count: 50
#   Total Explicit Count: 8896532
# ----------------------------------------
# Artist: grindcore
#   Total Duration (ms): 439
#   Average Duration (ms): 8.96
#   Track Count: 49
#   Total Explicit Count: 5807575
# ----------------------------------------
# Artist: groove
#   Total Duration (ms): 1766
#   Average Duration (ms): 35.32
#   Track Count: 50
#   Total Explicit Count: 10924247
# ----------------------------------------
# Artist: happy
#   Total Duration (ms): 2641
#   Average Duration (ms): 52.82
#   Track Count: 50
#   Total Explicit Count: 9244100
# ----------------------------------------
# Artist: hardstyle
#   Total Duration (ms): 1815
#   Average Duration (ms): 36.30
#   Track Count: 50
#   Total Explicit Count: 7517675
# ----------------------------------------
# Artist: holidays
#   Total Duration (ms): 1651
#   Average Duration (ms): 33.02
#   Track Count: 50
#   Total Explicit Count: 9779314
# ----------------------------------------
# Artist: honky-tonk
#   Total Duration (ms): 1456
#   Average Duration (ms): 29.12
#   Track Count: 50
#   Total Explicit Count: 9441264
# ----------------------------------------
# Artist: house
#   Total Duration (ms): 2431
#   Average Duration (ms): 48.62
#   Track Count: 50
#   Total Explicit Count: 10364534
# ----------------------------------------
# Artist: idm
#   Total Duration (ms): 1818
#   Average Duration (ms): 36.36
#   Track Count: 50
#   Total Explicit Count: 9494522
# ----------------------------------------
# Artist: indian
#   Total Duration (ms): 1664
#   Average Duration (ms): 33.28
#   Track Count: 50
#   Total Explicit Count: 9942889
# ----------------------------------------
# Artist: industrial
#   Total Duration (ms): 843
#   Average Duration (ms): 16.86
#   Track Count: 50
#   Total Explicit Count: 12409465
# ----------------------------------------
# Artist: j-dance
#   Total Duration (ms): 1258
#   Average Duration (ms): 25.16
#   Track Count: 50
#   Total Explicit Count: 10698670
# ----------------------------------------
# Artist: j-rock
#   Total Duration (ms): 1821
#   Average Duration (ms): 36.42
#   Track Count: 50
#   Total Explicit Count: 10544093
# ----------------------------------------
# Artist: metal
#   Total Duration (ms): 1969
#   Average Duration (ms): 40.18
#   Track Count: 49
#   Total Explicit Count: 12316343
# ----------------------------------------
# Artist: metalcore
#   Total Duration (ms): 1580
#   Average Duration (ms): 31.60
#   Track Count: 50
#   Total Explicit Count: 9513576
# ----------------------------------------
# Artist: mpb
#   Total Duration (ms): 986
#   Average Duration (ms): 19.72
#   Track Count: 50
#   Total Explicit Count: 11160611
# ----------------------------------------
# Artist: pop-film
#   Total Duration (ms): 733
#   Average Duration (ms): 14.66
#   Track Count: 50
#   Total Explicit Count: 8684323
# ----------------------------------------
# Artist: power-pop
#   Total Duration (ms): 1154
#   Average Duration (ms): 23.08
#   Track Count: 50
#   Total Explicit Count: 12127796
# ----------------------------------------
# Artist: rock
#   Total Duration (ms): 2841
#   Average Duration (ms): 60.45
#   Track Count: 47
#   Total Explicit Count: 10274541
# ----------------------------------------
# Artist: rockabilly
#   Total Duration (ms): 642
#   Average Duration (ms): 12.84
#   Track Count: 50
#   Total Explicit Count: 7894196
# ----------------------------------------
# Artist: romance
#   Total Duration (ms): 1705
#   Average Duration (ms): 34.10
#   Track Count: 50
#   Total Explicit Count: 10628031
# ----------------------------------------
# Artist: salsa
#   Total Duration (ms): 1825
#   Average Duration (ms): 36.50
#   Track Count: 50
#   Total Explicit Count: 10539004
# ----------------------------------------
# Artist: sleep
#   Total Duration (ms): 2624
#   Average Duration (ms): 53.55
#   Track Count: 49
#   Total Explicit Count: 10193855
# ----------------------------------------
# Artist: songwriter
#   Total Duration (ms): 376
#   Average Duration (ms): 10.74
#   Track Count: 35
#   Total Explicit Count: 7691502
# ----------------------------------------
# Artist: soundtracks
#   Total Duration (ms): 819
#   Average Duration (ms): 16.38
#   Track Count: 50
#   Total Explicit Count: 9418652
# ----------------------------------------
# Artist: study
#   Total Duration (ms): 1148
#   Average Duration (ms): 22.96
#   Track Count: 50
#   Total Explicit Count: 7135485
# ----------------------------------------
# Artist: trance
#   Total Duration (ms): 1717
#   Average Duration (ms): 34.34
#   Track Count: 50
#   Total Explicit Count: 9029137
# ----------------------------------------
# Artist: trip-hop
#   Total Duration (ms): 1150
#   Average Duration (ms): 23.00
#   Track Count: 50
#   Total Explicit Count: 9476861
# ----------------------------------------
# Artist: world-music
#   Total Duration (ms): 1128
#   Average Duration (ms): 22.56
#   Track Count: 50
#   Total Explicit Count: 9041387
# ----------------------------------------

# %%
#wrap up by stopping the Spark context and handling any necessary cleanup.
# Stop the SparkContext
sc.stop()
